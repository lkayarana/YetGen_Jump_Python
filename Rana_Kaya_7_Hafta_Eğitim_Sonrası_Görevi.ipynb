# %% [markdown]
# <a href="https://colab.research.google.com/github/lkayarana/YetGen_Jump_Python/blob/main/Rana_Kaya_7_Hafta_E%C4%9Fitim_Sonras%C4%B1_G%C3%B6revi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
# 1. problemimiz için kodlarını buraya yazabilirsin.
import time

def vki_hesaplama(kilo, boy):
  vki=kilo/(boy**2)
  return round(vki, 1)

def deger_araligi(vki):
  if vki<18.5:
    return "zayıf"
  elif vki<=24.9:
    return "normal kilolu"
  elif vki<=29.9:
    return "fazla kilolu"
  elif vki<=39.9:
    return "obez"
  elif vki>=40:
    return "ileri derecede obez"

def cikti_olustur(isim, yas, kilo, boy, vki, deger):
  kayit_tarihi=time.ctime(time.time())
  t1=f"Kullanıcı adı {isim}\n"
  t2=f"Kullanıcının yaş, kilo, boy bilgisi {yas}, {kilo}, {boy}\n"
  t3=f"Kullanıcının vücut-kitle indexi {vki}\n"
  t4=f"Değer aralığı {deger}\n"
  t5=f"oluşturulma tarihi {kayit_tarihi}\n"
  
  output=t1+t2+t3+t4+t5
  return output
  
def main():

  giris_sayisi=int(input("Kaç kullanıcı girişi yapacaksınız?: "))

  for i in range(giris_sayisi):
    print(f"kullanıcı kaydı {i+1}")

    isim=input("İsim ve soyisim giriniz: ")
    yas=int(input("Yaş giriniz: "))
    boy=float(input("Boy giriniz(m): "))
    kilo=float(input("Kilo giriniz(kg): "))

    vki=vki_hesaplama(kilo, boy)
    deger=deger_araligi(vki)
    output=cikti_olustur(isim, yas, kilo, boy, vki, deger)

    with open("saglık.txt", "a") as f:
      f.write(output)
      f.write("*"*20)
      f.write("\n")
      print("Kullancı bilgileri kaydedildi.")

  print("Veriler 'saglık.txt' dosyasına kaydedildi.\n ")

main()
# Out:
# Kaç kullanıcı girişi yapacaksınız?: 1
# kullanıcı kaydı 1
# İsim ve soyisim giriniz: rana kaya
# Yaş giriniz: 23
# Boy giriniz(m): 1.63
# Kilo giriniz(kg): 48
# Kullancı bilgileri kaydedildi.
# Veriler 'saglık.txt' dosyasına kaydedildi.

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
# 2. problemimiz için kodlarını buraya yazabilirsin.
menu = {
    "elma":0.5,
    "armut":0.75,
    "üzüm":2.,
    "çilek":1.5,
    "muz":1.,
    "kavun":1.56,
    "karpuz":1.99,
    "passion fruit":3.75,
    "mango":2.5
}


def display_menu():
  print("-------------YETBAR MENU------------")
  for item in list(menu.keys()):
    print(f"{item.upper():<10} : {menu[item]} TL")

def tek_urun_fiyat_hesaplama(urun, adet):
  assert adet>=0, "Ürün adedi 0 ve 0'dan küçük olamaz."
  if urun not in list(menu.keys()):
    return None
  else:
    return menu[urun]*adet

def satin_alma():
  display_menu()
  print("Lütfen satın almak istediğiniz ürünü giriniz.\nÇıkış yapmak içim '0'ı tuşlayınız.")

  satin_alinan_urunler=[]
  satin_alma_adedi=[]

  son_fiyat=0

  while 1:
    eklenecek_urun=input("Hangi üründen eklemek istiyorsunuz? ")
    if eklenecek_urun=="0":
      print("Fiş kaydediliyor...")
      break

    ekleme_adedi=int(input("Kaç adet eklemek istiyorsunuz? "))
    fiyat=tek_urun_fiyat_hesaplama(eklenecek_urun, ekleme_adedi)

    if fiyat is None:
      print("Yanlış bir giriş yaptınız, ürün eklenemedi.")
    else:
      print(f"Satın alma ücreti: {fiyat}.\nSatın almayı onaylamak için 'y' iptal etmek için 'n' giriniz. ")
      check=input("Satın almayı onaylıyor musunuz? ")
      if check=="y":
        print("Satın alım onaylandı.")
        print("-"*40)
        son_fiyat += fiyat
        satin_alinan_urunler.append(eklenecek_urun)
        satin_alma_adedi.append(ekleme_adedi)
        print(f"Ara toplam: {son_fiyat}")
      elif check == "n":
        print("Satın alma işlemi iptal edildi. ")
        print("-"*40)
  return son_fiyat, satin_alinan_urunler, satin_alma_adedi

def main():
  print("YetBar'a Hoşgeldiniz!\nMenüyü görüntülemek için '1'e, smoothie yapmak için lütfen '2'ye basınız.\nÇıkmak için lütfen '0'ı tuşlayınız.")
  
  program=None
  while 1:
    program=int(input("Tercihiniz: "))
    if program<0 or program>2:
      print("Yanlış bir tercih yaptınız. Tekrar deneyiniz.")
    elif program==0:
      print("Çıkış yapılıyor...\nSağlıklı günler dileriz.")
      break
    elif program==1:
      display_menu()
    elif program==2:
      satin_alma_ucreti, satin_alinan_urunler, satin_alma_adedi=satin_alma()

      with open("kasa.txt", "a") as f:
        f.write(str(time.ctime(time.time())))
        f.write("\n")
        f.write(','.join(map(str, satin_alinan_urunler)))
        f.write("\n")
        f.write(','.join(map(str, satin_alma_adedi)))
        f.write("\n")
        f.write(f"Toplam: {satin_alma_ucreti}")
        f.write("\n")
        f.write("*"*20)
        f.write("\n")
      
      cikis_kontrol=input("Başka bir işlem yapmak istiyor musunuz? (evet-hayır): ")
      if cikis_kontrol=="evet":
        pass
      else:
        print("\n\nTEŞEKKÜRLER")
        break
main()
# Out:
# YetBar'a Hoşgeldiniz!
# Menüyü görüntülemek için '1'e, smoothie yapmak için lütfen '2'ye basınız.
# Çıkmak için lütfen '0'ı tuşlayınız.
# Tercihiniz: 1
# -------------YETBAR MENU------------
# ELMA       : 0.5 TL
# ARMUT      : 0.75 TL
# ÜZÜM       : 2.0 TL
# ÇILEK      : 1.5 TL
# MUZ        : 1.0 TL
# KAVUN      : 1.56 TL
# KARPUZ     : 1.99 TL
# PASSION FRUIT : 3.75 TL
# MANGO      : 2.5 TL
# Tercihiniz: 2
# -------------YETBAR MENU------------
# ELMA       : 0.5 TL
# ARMUT      : 0.75 TL
# ÜZÜM       : 2.0 TL
# ÇILEK      : 1.5 TL
# MUZ        : 1.0 TL
# KAVUN      : 1.56 TL
# KARPUZ     : 1.99 TL
# PASSION FRUIT : 3.75 TL
# MANGO      : 2.5 TL
# Lütfen satın almak istediğiniz ürünü giriniz.
# Çıkış yapmak içim '0'ı tuşlayınız.
# Hangi üründen eklemek istiyorsunuz? mu<
# Kaç adet eklemek istiyorsunuz? 3
# Yanlış bir giriş yaptınız, ürün eklenemedi.
# Hangi üründen eklemek istiyorsunuz? muz
# Kaç adet eklemek istiyorsunuz? 3
# Satın alma ücreti: 3.0.
# Satın almayı onaylamak için 'y' iptal etmek için 'n' giriniz.
# Satın almayı onaylıyor musunuz? y
# Satın alım onaylandı.
# ----------------------------------------
# Ara toplam: 3.0
# Hangi üründen eklemek istiyorsunuz? çilek
# Kaç adet eklemek istiyorsunuz? 1
# Satın alma ücreti: 1.5.
# Satın almayı onaylamak için 'y' iptal etmek için 'n' giriniz.
# Satın almayı onaylıyor musunuz? y
# Satın alım onaylandı.
# ----------------------------------------
# Ara toplam: 4.5
# Hangi üründen eklemek istiyorsunuz? kavun
# Kaç adet eklemek istiyorsunuz? 2
# Satın alma ücreti: 3.12.
# Satın almayı onaylamak için 'y' iptal etmek için 'n' giriniz.
# Satın almayı onaylıyor musunuz? 0
# Hangi üründen eklemek istiyorsunuz? 0
# Fiş kaydediliyor...
# Başka bir işlem yapmak istiyor musunuz? (evet-hayır): hayır
#
#
# TEŞEKKÜRLER
